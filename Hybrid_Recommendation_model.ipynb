# %% [markdown]
# I was working on a movie recommendation system project. While content-based filtering could recommend similar movies based on genre or tags, and collaborative filtering could learn from user preferences, both approaches had limitations when used alone.
# Content-based systems lacked diversity, while collaborative filtering struggled with new users or movies.
#
# My task was to build a hybrid recommendation system that could combine the strengths of both approaches — to provide more accurate and personalized movie recommendations, even in cold-start scenarios.
#
# I followed a structured process:
#
# Data Preparation: Used a movie ratings dataset (like MovieLens), and combined it with metadata such as genres, tags, and movie descriptions.
#
# Content-Based Filtering:
#
# Created TF-IDF vectors from movie genres and tags.
#
# Calculated cosine similarity to find movies similar to a user’s liked movies.
#
# Collaborative Filtering:
#
# Used SVD to learn latent factors for users and items from the rating matrix.
#
# Hybrid Model:
#
# Combined both scores:
#
# For each user, I gave weights to content similarity and predicted ratings from SVD.
#
# This gave a personalized and diverse recommendation list, even for users with very few ratings.
#
# The hybrid recommendation system provided more relevant and personalized movie suggestions by combining both user preferences and movie characteristics.
# It overcame common limitations like the cold-start problem by using content features for new users or movies.
# Users received a balanced mix of familiar and diverse movie options — improving both user satisfaction and discovery.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 83.9 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.16.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2469545 sha256=cf834d1a609e9e3b69d7752c22cbfa24eb45dfb9055168c9d36b3c07faa09872
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %%
from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')

# %%
df = pd.merge(movies[['movieId', 'title']], ratings, on='movieId', how = 'right')

# %%
df_ratings = df.drop(columns = 'timestamp')

# %%
df_ratings.shape
# Out:
# (6160306, 4)

# %%
df_ratings['movie_release_year'] = df_ratings['title'].str.extract(r'\((\d{4})\)')
df_ratings['movie_name'] = df_ratings['title'].str.replace(r'\s*\(\d{4}\)', '', regex=True)

# %%
print('total number of customers', df_ratings['userId'].nunique())
print('total number of movies', df_ratings['movieId'].nunique())
print('unique years', df_ratings['movie_release_year'].nunique())
# Out:
# total number of customers 39896
# total number of movies 41618
# unique years 134

# %%
customer_list15 = df.groupby('userId')['rating'].count().sort_values(ascending = False).reset_index().query('rating > 15')['userId'].tolist()

# %%
ratings = df_ratings[df_ratings['userId'].isin(customer_list15)]

# %%
top_movie_rating_count = ratings.groupby('movie_name')['rating'].count().sort_values(ascending = False).reset_index().head(10)

# %%
sns.barplot(data = top_movie_rating_count, y = 'movie_name', x = 'rating', palette = 'spring')
plt.show()

# %%
top_year_released = ratings.groupby('movie_release_year')['movie_name'].count().sort_values(ascending = False).reset_index().head(10)

# %%
sns.barplot(data = top_year_released, x = 'movie_release_year', y = 'movie_name', palette = 'spring')
plt.show()

# %%
sns.kdeplot(data = ratings, x = 'rating', fill = True)
plt.show()

# %%
reader = Reader(rating_scale = (0.5, 5))

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %%
svd = SVD(n_factors=25, n_epochs=30, random_state=42, verbose=True)
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29

# %%
id_to_names = {}

for id, name in zip(ratings['movieId'], ratings['movie_name']):
    id_to_names[id] = name

# %%
id_to_names
# Out:
# {296: 'Pulp Fiction',
#  306: 'Three Colors: Red (Trois couleurs: Rouge)',
#  307: 'Three Colors: Blue (Trois couleurs: Bleu)',
#  665: 'Underground',
#  899: "Singin' in the Rain",
#  1088: 'Dirty Dancing',
#  1175: 'Delicatessen',
#  1217: 'Ran',
#  1237: 'Seventh Seal, The (Sjunde inseglet, Det)',
#  1250: 'Bridge on the River Kwai, The',
#  1260: 'M',
#  1653: 'Gattaca',
#  2011: 'Back to the Future Part II',
#  2012: 'Back to the Future Part III',
#  2068: 'Fanny and Alexander (Fanny och Alexander)',
#  2161: 'NeverEnding Story, The',
#  2351: 'Nights of Cabiria (Notti di Cabiria, Le)',
#  2573: 'Tango',
#  2632: 'Saragossa Manuscript, The (Rekopis znaleziony w Saragossie)',
#  2692: 'Run Lola Run (Lola rennt)',
#  2843: 'Black Cat, White Cat (Crna macka, beli macor)',
#  3448: 'Good Morning, Vietnam',
#  3569: 'Idiots, The (Idioterne)',
#  3949: 'Requiem for a Dream',
#  4144: 'In the Mood For Love (Fa yeung nin wa)',
#  4308: 'Moulin Rouge',
#  4325: 'Night, The (Notte, La)',
#  4422: 'Cries and Whispers (Viskningar och rop)',
#  4703: 'Chocolat',
#  4973: "Amelie (Fabuleux destin d'Amélie Poulain, Le)",
#  5147: 'Wild Strawberries (Smultronstället)',
#  5269: 'Piano Teacher, The (La pianiste)',
#  5684: 'Naqoyqatsi',
#  5767: 'Teddy Bear (Mis)',
#  5878: 'Talk to Her (Hable con Ella)',
#  5912: 'Hit the Bank (Vabank)',
#  5952: 'Lord of the Rings: The Two Towers, The',
#  6016: 'City of God (Cidade de Deus)',
#  6370: "Spanish Apartment, The (L'auberge espagnole)",
#  6377: 'Finding Nemo',
#  6539: 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  6711: 'Lost in Translation',
#  6954: 'Barbarian Invasions, The (Les invasions barbares)',
#  7209: "M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vacances de Monsieur Hulot, Les)",
#  7234: 'Strada, La',
#  7318: 'Passion of the Christ, The',
#  7323: 'Good bye, Lenin!',
#  7327: 'Persona',
#  7361: 'Eternal Sunshine of the Spotless Mind',
#  7365: 'Noi the Albino (Nói albinói)',
#  7820: 'Virgin Spring, The (Jungfrukällan)',
#  7937: 'Silence, The (Tystnaden)',
#  7938: 'Winter Light (Nattvardsgästerna)',
#  7939: 'Through a Glass Darkly (Såsom i en spegel)',
#  7940: 'The Magician',
#  8014: 'Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom)',
#  8154: 'Dolce Vita, La',
#  8327: 'Dolls',
#  8360: 'Shrek 2',
#  8405: 'Hour of the Wolf (Vargtimmen)',
#  8685: 'Miracle of Marcelino, The (Marcelino pan y vino)',
#  8729: 'Swann in Love (Un amour de Swann)',
#  8786: 'Port of Shadows (Quai des brumes)',
#  8873: 'Motorcycle Diaries, The (Diarios de motocicleta)',
#  8973: 'Bad Education (La mala educación)',
#  27193: 'Taxi 2',
#  27266: '2046',
#  27721: 'Very Long Engagement, A (Un long dimanche de fiançailles)',
#  31956: '5x2',
#  32591: 'Look at Me (Comme une image)',
#  1: 'Toy Story',
#  62: "Mr. Holland's Opus",
#  110: 'Braveheart',
#  150: 'Apollo 13',
#  151: 'Rob Roy',
#  236: 'French Kiss',
#  260: 'Star Wars: Episode IV - A New Hope',
#  261: 'Little Women',
#  266: 'Legends of the Fall',
#  318: 'Shawshank Redemption, The',
#  333: 'Tommy Boy',
#  349: 'Clear and Present Danger',
#  356: 'Forrest Gump',
#  364: 'Lion King, The',
#  380: 'True Lies',
#  457: 'Fugitive, The',
#  480: 'Jurassic Park',
#  497: 'Much Ado About Nothing',
#  524: 'Rudy',
#  527: "Schindler's List",
#  534: 'Shadowlands',
#  553: 'Tombstone',
#  588: 'Aladdin',
#  589: 'Terminator 2: Judgment Day',
#  653: 'Dragonheart',
#  733: 'Rock, The',
#  858: 'Godfather, The',
#  914: 'My Fair Lady',
#  953: "It's a Wonderful Life",
#  1035: 'Sound of Music, The',
#  1080: "Monty Python's Life of Brian",
#  1136: 'Monty Python and the Holy Grail',
#  1196: 'Star Wars: Episode V - The Empire Strikes Back',
#  1197: 'Princess Bride, The',
#  1198: 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)',
#  1201: 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)',
#  1210: 'Star Wars: Episode VI - Return of the Jedi',
#  1246: 'Dead Poets Society',
#  1257: 'Better Off Dead...',
#  1270: 'Back to the Future',
#  1271: 'Fried Green Tomatoes',
#  1275: 'Highlander',
#  1283: 'High Noon',
#  1287: 'Ben-Hur',
#  1291: 'Indiana Jones and the Last Crusade',
#  1293: 'Gandhi',
#  1299: 'Killing Fields, The',
#  1302: 'Field of Dreams',
#  1356: 'Star Trek: First Contact',
#  1374: 'Star Trek II: The Wrath of Khan',
#  1376: 'Star Trek IV: The Voyage Home',
#  1393: 'Jerry Maguire',
#  1431: 'Beverly Hills Ninja',
#  1465: 'Rosewood',
#  1485: 'Liar Liar',
#  1488: "Devil's Own, The",
#  1527: 'Fifth Element, The',
#  1580: 'Men in Black (a.k.a. MIB)',
#  1584: 'Contact',
#  1587: 'Conan the Barbarian',
#  1610: 'Hunt for Red October, The',
#  1672: 'Rainmaker, The',
#  1674: 'Witness',
#  1682: 'Truman Show, The',
#  1693: 'Amistad',
#  1722: 'Tomorrow Never Dies',
#  1873: 'Misérables, Les',
#  1907: 'Mulan',
#  1923: "There's Something About Mary",
#  1957: 'Chariots of Fire',
#  1968: 'Breakfast Club, The',
#  2028: 'Saving Private Ryan',
#  2081: 'Little Mermaid, The',
#  2083: 'Muppet Christmas Carol, The',
#  2115: 'Indiana Jones and the Temple of Doom',
#  2138: 'Watership Down',
#  2139: 'Secret of NIMH, The',
#  2150: 'Gods Must Be Crazy, The',
#  2194: 'Untouchables, The',
#  2268: 'Few Good Men, A',
#  2273: 'Rush Hour',
#  2294: 'Antz',
#  2324: 'Life Is Beautiful (La Vita è bella)',
#  2355: "Bug's Life, A",
#  2359: 'Waking Ned Devine (a.k.a. Waking Ned)',
#  2406: 'Romancing the Stone',
#  2470: 'Crocodile Dundee',
#  2496: 'Blast from the Past',
#  2501: 'October Sky',
#  2571: 'Matrix, The',
#  2617: 'Mummy, The',
#  2640: 'Superman',
#  2643: 'Superman IV: The Quest for Peace',
#  2694: 'Big Daddy',
#  2720: 'Inspector Gadget',
#  2745: 'Mission, The',
#  2761: 'Iron Giant, The',
#  2762: 'Sixth Sense, The',
#  2797: 'Big',
#  2918: "Ferris Bueller's Day Off",
#  2987: 'Who Framed Roger Rabbit?',
#  3098: 'Natural, The',
#  3105: 'Awakenings',
#  3107: 'Backdraft',
#  3114: 'Toy Story 2',
#  3148: 'Cider House Rules, The',
#  3175: 'Galaxy Quest',
#  3360: 'Hoosiers (a.k.a. Best Shot)',
#  3396: 'Muppet Movie, The',
#  3479: 'Ladyhawke',
#  3510: 'Frequency',
#  3578: 'Gladiator',
#  3793: 'X-Men',
#  3889: 'Highlander: Endgame (Highlander IV)',
#  3916: 'Remember the Titans',
#  3948: 'Meet the Parents',
#  3994: 'Unbreakable',
#  4016: "Emperor's New Groove, The",
#  4019: 'Finding Forrester',
#  4022: 'Cast Away',
#  4023: 'Family Man, The',
#  4103: 'Empire of the Sun',
#  4299: "Knight's Tale, A",
#  4306: 'Shrek',
#  4535: 'Man from Snowy River, The',
#  4571: "Bill & Ted's Excellent Adventure",
#  4720: 'Others, The',
#  4857: 'Fiddler on the Roof',
#  4874: 'K-PAX',
#  4886: 'Monsters, Inc.',
#  4896: "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)",
#  4963: "Ocean's Eleven",
#  4993: 'Lord of the Rings: The Fellowship of the Ring, The',
#  4995: 'Beautiful Mind, A',
#  5010: 'Black Hawk Down',
#  5103: 'Sandlot, The',
#  5349: 'Spider-Man',
#  5418: 'Bourne Identity, The',
#  5445: 'Minority Report',
#  5574: 'Transporter, The',
#  5816: 'Harry Potter and the Chamber of Secrets',
#  5955: 'Antwone Fisher',
#  6156: 'Shanghai Knights',
#  6157: 'Daredevil',
#  6213: 'Tears of the Sun',
#  6287: 'Anger Management',
#  6311: 'Other Side of Heaven, The',
#  6333: 'X2: X-Men United',
#  6565: 'Seabiscuit',
#  6753: 'Secondhand Lions',
#  6879: 'Runaway Jury',
#  6947: 'Master and Commander: The Far Side of the World',
#  7004: 'Kindergarten Cop',
#  7007: 'Last Boy Scout, The',
#  7075: 'Court Jester, The',
#  7090: 'Hero (Ying xiong)',
#  7143: 'Last Samurai, The',
#  7153: 'Lord of the Rings: The Return of the King, The',
#  7162: 'Cold Mountain',
#  7386: 'Ten Commandments, The',
#  7624: 'School Ties',
#  8010: 'Power of One, The',
#  8368: 'Harry Potter and the Prisoner of Azkaban',
#  8636: 'Spider-Man 2',
#  8665: 'Bourne Supremacy, The',
#  8958: 'Ray',
#  8961: 'Incredibles, The',
#  8970: 'Finding Neverland',
#  27821: 'Interpreter, The',
#  30749: 'Hotel Rwanda',
#  30848: 'Love Song for Bobby Long, A',
#  31923: 'Three Musketeers, The',
#  33166: 'Crash',
#  33493: 'Star Wars: Episode III - Revenge of the Sith',
#  33660: 'Cinderella Man',
#  33794: 'Batman Begins',
#  34162: 'Wedding Crashers',
#  35836: '40-Year-Old Virgin, The',
#  36527: 'Proof',
#  40815: 'Harry Potter and the Goblet of Fire',
#  29: 'City of Lost Children, The (Cité des enfants perdus, La)',
#  32: 'Twelve Monkeys (a.k.a. 12 Monkeys)',
#  50: 'Usual Suspects, The',
#  111: 'Taxi Driver',
#  172: 'Johnny Mnemonic',
#  173: 'Judge Dredd',
#  214: 'Before the Rain (Pred dozhdot)',
#  293: 'Léon: The Professional (a.k.a. The Professional) (Léon)',
#  442: 'Demolition Man',
#  541: 'Blade Runner',
#  593: 'Silence of the Lambs, The',
#  741: 'Ghost in the Shell (Kôkaku kidôtai)',
#  745: 'Wallace & Gromit: A Close Shave',
#  778: 'Trainspotting',
#  780: 'Independence Day (a.k.a. ID4)',
#  912: 'Casablanca',
#  913: 'Maltese Falcon, The',
#  924: '2001: A Space Odyssey',
#  1089: 'Reservoir Dogs',
#  1127: 'Abyss, The',
#  1148: 'Wallace & Gromit: The Wrong Trousers',
#  1200: 'Aliens',
#  1206: 'Clockwork Orange, A',
#  1208: 'Apocalypse Now',
#  1213: 'Goodfellas',
#  1214: 'Alien',
#  1221: 'Godfather: Part II, The',
#  1222: 'Full Metal Jacket',
#  1240: 'Terminator, The',
#  1252: 'Chinatown',
#  1274: 'Akira',
#  1320: 'Alien³ (a.k.a. Alien 3)',
#  1676: 'Starship Troopers',
#  1732: 'Big Lebowski, The',
#  1748: 'Dark City',
#  1882: 'Godzilla',
#  1909: 'X-Files: Fight the Future, The',
#  1960: 'Last Emperor, The',
#  2019: 'Seven Samurai (Shichinin no samurai)',
#  2021: 'Dune',
#  2105: 'Tron',
#  2329: 'American History X',
#  2542: 'Lock, Stock & Two Smoking Barrels',
#  2628: 'Star Wars: Episode I - The Phantom Menace',
#  2641: 'Superman II',
#  2858: 'American Beauty',
#  2938: 'Man Facing Southeast',
#  2959: 'Fight Club',
#  3091: 'Kagemusha',
#  3156: 'Bicentennial Man',
#  3285: 'Beach, The',
#  3300: 'Pitch Black',
#  3301: 'Whole Nine Yards, The',
#  3328: 'Ghost Dog: The Way of the Samurai',
#  3408: 'Erin Brockovich',
#  3452: 'Romeo Must Die',
#  3471: 'Close Encounters of the Third Kind',
#  3484: 'Skulls, The',
#  3527: 'Predator',
#  3534: '28 Days',
#  3535: 'American Psycho',
#  3646: "Big Momma's House",
#  3702: 'Mad Max',
#  3730: 'Conversation, The',
#  3744: 'Shaft',
#  3745: 'Titan A.E.',
#  3751: 'Chicken Run',
#  3753: 'Patriot, The',
#  3755: 'Perfect Storm, The',
#  3785: 'Scary Movie',
#  3798: 'What Lies Beneath',
#  3825: 'Coyote Ugly',
#  3827: 'Space Cowboys',
#  3863: 'Cell, The',
#  3879: 'Art of War, The',
#  3968: 'Bedazzled',
#  3969: 'Pay It Forward',
#  3977: "Charlie's Angels",
#  3979: 'Little Nicky',
#  3980: 'Men of Honor',
#  3986: '6th Day, The',
#  3988: 'How the Grinch Stole Christmas (a.k.a. The Grinch)',
#  3991: '102 Dalmatians',
#  3993: 'Quills',
#  3996: 'Crouching Tiger, Hidden Dragon (Wo hu cang long)',
#  3999: 'Vertical Limit',
#  4011: 'Snatch',
#  4018: 'What Women Want',
#  4025: 'Miss Congeniality',
#  4027: 'O Brother, Where Art Thou?',
#  4034: 'Traffic',
#  4069: 'Wedding Planner, The',
#  4148: 'Hannibal',
#  4167: '15 Minutes',
#  4226: 'Memento',
#  4232: 'Spy Kids',
#  4234: 'Tailor of Panama, The',
#  4246: "Bridget Jones's Diary",
#  4262: 'Scarface',
#  4340: 'Animal, The',
#  4343: 'Evolution',
#  4344: 'Swordfish',
#  4366: 'Atlantis: The Lost Empire',
#  4367: 'Lara Croft: Tomb Raider',
#  4368: 'Dr. Dolittle 2',
#  4369: 'Fast and the Furious, The',
#  4383: 'Crimson Rivers, The (Rivières pourpres, Les)',
#  4388: 'Scary Movie 2',
#  4447: 'Legally Blonde',
#  4448: 'Score, The',
#  4643: 'Planet of the Apes',
#  4701: 'Rush Hour 2',
#  4718: 'American Pie 2',
#  4776: 'Training Day',
#  4816: 'Zoolander',
#  4844: 'Bandits',
#  4866: 'Last Castle, The',
#  4887: 'One, The',
#  4901: 'Spy Game',
#  4958: 'Behind Enemy Lines',
#  4975: 'Vanilla Sky',
#  4979: 'Royal Tenenbaums, The',
#  4992: 'Kate & Leopold',
#  5004: 'Party, The',
#  5013: 'Gosford Park',
#  5014: 'I Am Sam',
#  5108: 'John Q',
#  5218: 'Ice Age',
#  5219: 'Resident Evil',
#  5225: 'And Your Mother Too (Y tu mamá también)',
#  5254: 'Blade II',
#  5266: 'Panic Room',
#  5291: 'Rashomon (Rashômon)',
#  5293: 'Changing Lanes',
#  5313: 'The Scorpion King',
#  5364: 'Unfaithful',
#  5377: 'About a Boy',
#  5378: 'Star Wars: Episode II - Attack of the Clones',
#  5388: 'Insomnia',
#  5400: 'Sum of All Fears, The',
#  5449: 'Mr. Deeds',
#  5459: 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2)',
#  5479: 'K-19: The Widowmaker',
#  5502: 'Signs',
#  5507: 'xXx',
#  5528: 'One Hour Photo',
#  5630: 'Red Dragon',
#  5669: 'Bowling for Columbine',
#  5679: 'Ring, The',
#  5782: 'Professional, The (Le professionnel)',
#  5785: 'Jackass: The Movie',
#  5810: '8 Mile',
#  5853: 'Scanners',
#  5872: 'Die Another Day',
#  5900: 'Analyze That',
#  5903: 'Equilibrium',
#  5944: 'Star Trek: Nemesis',
#  5945: 'About Schmidt',
#  5954: '25th Hour',
#  5956: 'Gangs of New York',
#  5959: 'Narc',
#  5989: 'Catch Me If You Can',
#  5991: 'Chicago',
#  6059: 'Recruit, The',
#  6155: 'How to Lose a Guy in 10 Days',
#  6281: 'Phone Booth',
#  6283: 'Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira)',
#  6323: 'Identity',
#  6365: 'Matrix Reloaded, The',
#  6373: 'Bruce Almighty',
#  6378: 'Italian Job, The',
#  6383: '2 Fast 2 Furious (Fast and the Furious 2, The)',
#  6440: 'Barton Fink',
#  6482: 'Dumb and Dumberer: When Harry Met Lloyd',
#  6502: '28 Days Later',
#  6534: 'Hulk',
#  6535: 'Legally Blonde 2: Red, White & Blonde',
#  6537: 'Terminator 3: Rise of the Machines',
#  6541: 'League of Extraordinary Gentlemen, The (a.k.a. LXG)',
#  6548: 'Bad Boys II',
#  6550: 'Johnny English',
#  6564: 'Lara Croft Tomb Raider: The Cradle of Life',
#  6586: 'American Wedding (American Pie 3)',
#  6595: 'S.W.A.T.',
#  6708: 'Matchstick Men',
#  6754: 'Underworld',
#  6863: 'School of Rock',
#  6870: 'Mystic River',
#  6873: 'Intolerable Cruelty',
#  6874: 'Kill Bill: Vol. 1',
#  6934: 'Matrix Revolutions, The',
#  6952: 'Gothika',
#  7147: 'Big Fish',
#  7149: "Something's Gotta Give",
#  7154: 'Mona Lisa Smile',
#  7163: 'Paycheck',
#  7293: '50 First Dates',
#  7325: 'Starsky & Hutch',
#  7346: 'Girl Next Door, The',
#  7347: 'Secret Window',
#  7373: 'Hellboy',
#  7438: 'Kill Bill: Vol. 2',
#  7439: 'Punisher, The',
#  7445: 'Man on Fire',
#  7454: 'Van Helsing',
#  7458: 'Troy',
#  8361: 'Day After Tomorrow, The',
#  8370: 'Blind Swordsman: Zatoichi, The (Zatôichi)',
#  8371: 'Chronicles of Riddick, The',
#  8528: 'Dodgeball: A True Underdog Story',
#  8529: 'Terminal, The',
#  8641: 'Anchorman: The Legend of Ron Burgundy',
#  8644: 'I, Robot',
#  8666: 'Catwoman',
#  8781: 'Manchurian Candidate, The',
#  8783: 'Village, The',
#  8798: 'Collateral',
#  8810: 'AVP: Alien vs. Predator',
#  8861: 'Resident Evil: Apocalypse',
#  8865: 'Sky Captain and the World of Tomorrow',
#  8874: 'Shaun of the Dead',
#  8965: 'Polar Express, The',
#  8969: 'Bridget Jones: The Edge of Reason',
#  8983: 'House of Flying Daggers (Shi mian mai fu)',
#  8984: "Ocean's Twelve",
#  8985: 'Blade: Trinity',
#  27134: 'Dark Portals: The Chronicles of Vidocq  (Vidocq)',
#  27660: 'Animatrix, The',
#  27706: "Lemony Snicket's A Series of Unfortunate Events",
#  27728: 'Ghost in the Shell 2: Innocence (a.k.a. Innocence) (Inosensu)',
#  27773: 'Old Boy',
#  27793: 'Starship Troopers 2: Hero of the Federation',
#  27803: 'Sea Inside, The (Mar adentro)',
#  27808: 'Spanglish',
#  30707: 'Million Dollar Baby',
#  30793: 'Charlie and the Chocolate Factory',
#  30825: 'Meet the Fockers',
#  31184: 'Appleseed (Appurushîdo)',
#  31221: 'Elektra',
#  31685: 'Hitch',
#  31696: 'Constantine',
#  31804: 'Night Watch (Nochnoy dozor)',
#  31878: 'Kung Fu Hustle (Gong fu)',
#  32587: 'Sin City',
#  33004: "Hitchhiker's Guide to the Galaxy, The",
#  33615: 'Madagascar',
#  33679: 'Mr. & Mrs. Smith',
#  34048: 'War of the Worlds',
#  34150: 'Fantastic Four',
#  34319: 'Island, The',
#  34405: 'Serenity',
#  34437: 'Broken Flowers',
#  36519: 'Transporter 2',
#  36529: 'Lord of War',
#  37386: 'Aeon Flux',
#  37727: 'Flightplan',
#  37729: 'Corpse Bride',
#  37741: 'Capote',
#  39435: 'Legend of Zorro, The',
#  40583: 'Syriana',
#  40819: 'Walk the Line',
#  41566: 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#  41569: 'King Kong',
#  42738: 'Underworld: Evolution',
#  43928: 'Ultraviolet',
#  44022: 'Ice Age 2: The Meltdown',
#  44191: 'V for Vendetta',
#  45186: 'Mission: Impossible III',
#  45447: 'Da Vinci Code, The',
#  45499: 'X-Men: The Last Stand',
#  45501: 'Break-Up, The',
#  45517: 'Cars',
#  45666: 'Nacho Libre',
#  45672: 'Click',
#  45722: "Pirates of the Caribbean: Dead Man's Chest",
#  46335: 'Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The)',
#  46578: 'Little Miss Sunshine',
#  46965: 'Snakes on a Plane',
#  46970: 'Talladega Nights: The Ballad of Ricky Bobby',
#  46972: 'Night at the Museum',
#  47200: 'Crank',
#  47610: 'Illusionist, The',
#  48385: 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  48394: "Pan's Labyrinth (Laberinto del fauno, El)",
#  48516: 'Departed, The',
#  48738: 'Last King of Scotland, The',
#  48774: 'Children of Men',
#  48780: 'Prestige, The',
#  49272: 'Casino Royale',
#  49274: 'Happy Feet',
#  49278: 'Déjà Vu (Deja Vu)',
#  49530: 'Blood Diamond',
#  49822: 'Good Shepherd, The',
#  50068: 'Letters from Iwo Jima',
#  50872: 'Ratatouille',
#  51255: 'Hot Fuzz',
#  51662: '300',
#  51935: 'Shooter',
#  52604: 'Fracture',
#  52722: 'Spider-Man 3',
#  52950: 'Day Watch (Dnevnoy dozor)',
#  53121: 'Shrek the Third',
#  53125: "Pirates of the Caribbean: At World's End",
#  53129: 'Mr. Brooks',
#  53464: 'Fantastic Four: Rise of the Silver Surfer',
#  53972: 'Live Free or Die Hard',
#  53996: 'Transformers',
#  54001: 'Harry Potter and the Order of the Phoenix',
#  54286: 'Bourne Ultimatum, The',
#  54503: 'Superbad',
#  54648: 'Rush Hour 3',
#  54997: '3:10 to Yuma',
#  55232: 'Resident Evil: Extinction',
#  55765: 'American Gangster',
#  55805: "Before the Devil Knows You're Dead",
#  55820: 'No Country for Old Men',
#  56145: 'Mist, The',
#  56156: 'Hitman',
#  56171: 'Golden Compass, The',
#  56174: 'I Am Legend',
#  56587: 'Bucket List, The',
#  56782: 'There Will Be Blood',
#  56949: '27 Dresses',
#  57368: 'Cloverfield',
#  57528: 'Rambo (Rambo 4)',
#  57640: 'Hellboy II: The Golden Army',
#  57669: 'In Bruges',
#  58025: 'Jumper',
#  58559: 'Dark Knight, The',
#  59315: 'Iron Man',
#  59369: 'Taken',
#  59501: 'Chronicles of Narnia: Prince Caspian, The',
#  59615: 'Indiana Jones and the Kingdom of the Crystal Skull',
#  59784: 'Kung Fu Panda',
#  59900: "You Don't Mess with the Zohan",
#  60040: 'Incredible Hulk, The',
#  60069: 'WALL·E',
#  60072: 'Wanted',
#  60074: 'Hancock',
#  60126: 'Get Smart',
#  60684: 'Watchmen',
#  60756: 'Step Brothers',
#  60760: 'X-Files: I Want to Believe, The',
#  61132: 'Tropic Thunder',
#  61160: 'Star Wars: The Clone Wars',
#  61248: 'Death Race',
#  61323: 'Burn After Reading',
#  61350: 'Babylon A.D.',
#  62849: 'RocknRolla',
#  62999: 'Madagascar: Escape 2 Africa',
#  63062: 'Changeling',
#  63072: 'Road, The',
#  63113: 'Quantum of Solace',
#  63859: 'Bolt',
#  63876: 'Milk',
#  64030: 'Transporter 3',
#  64614: 'Gran Torino',
#  64839: 'Wrestler, The',
#  64957: 'Curious Case of Benjamin Button, The',
#  65514: 'Ip Man',
#  65682: 'Underworld: Rise of the Lycans',
#  66097: 'Coraline',
#  67255: 'Girl with the Dragon Tattoo, The (Män som hatar kvinnor)',
#  67923: 'Fast & Furious (Fast and the Furious 4, The)',
#  68157: 'Inglourious Basterds',
#  68319: 'X-Men Origins: Wolverine',
#  68358: 'Star Trek',
#  68554: 'Angels & Demons',
#  68791: 'Terminator Salvation',
#  68793: 'Night at the Museum: Battle of the Smithsonian',
#  68952: 'Drag Me to Hell',
#  69122: 'Hangover, The',
#  69481: 'Hurt Locker, The',
#  69526: 'Transformers: Revenge of the Fallen',
#  69640: 'Public Enemies',
#  69844: 'Harry Potter and the Half-Blood Prince',
#  70286: 'District 9',
#  70293: 'Julie & Julia',
#  70305: 'Race to Witch Mountain',
#  70336: 'G.I. Joe: The Rise of Cobra',
#  71057: '9',
#  71156: 'Men Who Stare at Goats, The',
#  71464: 'Serious Man, A',
#  71530: 'Surrogates',
#  71535: 'Zombieland',
#  72011: 'Up in the Air',
#  72209: 'Astro Boy',
#  72378: '2012',
#  72641: 'Blind Side, The',
#  72701: 'Planet 51',
#  72998: 'Avatar',
#  73017: 'Sherlock Holmes',
#  73268: 'Daybreakers',
#  73321: 'Book of Eli, The',
#  73323: "Girl Who Kicked the Hornet's Nest, The (Luftslottet som sprängdes)",
#  74458: 'Shutter Island',
#  74789: 'Alice in Wonderland',
#  76077: 'Hot Tub Time Machine',
#  76093: 'How to Train Your Dragon',
#  76251: 'Kick-Ass',
#  77561: 'Iron Man 2',
#  78469: 'A-Team, The',
#  78499: 'Toy Story 3',
#  79091: 'Despicable Me',
#  79132: 'Inception',
#  79224: 'Karate Kid, The',
#  79293: 'Salt',
#  79695: 'Expendables, The',
#  80363: 'Resident Evil: Afterlife',
#  80463: 'Social Network, The',
#  81229: 'Red',
#  81537: 'Due Date',
#  81564: 'Megamind',
#  81591: 'Black Swan',
#  81834: 'Harry Potter and the Deathly Hallows: Part 1',
#  81845: "King's Speech, The",
#  82095: 'Skyline',
#  82202: 'Tourist, The',
#  82461: 'Tron: Legacy',
#  83349: 'Green Hornet, The',
#  83613: 'Cowboys & Aliens',
#  84152: 'Limitless',
#  84772: 'Paul',
#  84954: 'Adjustment Bureau, The',
#  85020: 'Mechanic, The',
#  85056: 'I Am Number Four',
#  85131: 'Battle: Los Angeles',
#  85261: 'Mars Needs Moms',
#  85414: 'Source Code',
#  86332: 'Thor',
#  86644: 'Fast Five (Fast and the Furious 5, The)',
#  86880: 'Pirates of the Caribbean: On Stranger Tides',
#  86911: 'Hangover Part II, The',
#  87232: 'X-Men: First Class',
#  87306: 'Super 8',
#  87430: 'Green Lantern',
#  87520: 'Transformers: Dark of the Moon',
#  87876: 'Cars 2',
#  88125: 'Harry Potter and the Deathly Hallows: Part 2',
#  88140: 'Captain America: The First Avenger',
#  88405: 'Friends with Benefits',
#  88744: 'Rise of the Planet of the Apes',
#  89492: 'Moneyball',
#  89745: 'Avengers, The',
#  89753: 'Tinker Tailor Soldier Spy',
#  90249: 'Real Steel',
#  90866: 'Hugo',
#  91500: 'The Hunger Games',
#  91529: 'Dark Knight Rises, The',
#  91542: 'Sherlock Holmes: A Game of Shadows',
#  91630: 'Mission: Impossible - Ghost Protocol',
#  91658: 'Girl with the Dragon Tattoo, The',
#  91974: 'Underworld: Awakening',
#  91976: 'Grey, The',
#  93363: 'John Carter',
#  93805: 'Iron Sky',
#  94018: 'Battleship',
#  94677: 'Dictator, The',
#  94777: 'Men in Black III (M.III.B.) (M.I.B.³)',
#  94864: 'Prometheus',
#  95441: 'Ted',
#  95510: 'Amazing Spider-Man, The',
#  95875: 'Total Recall',
#  96079: 'Skyfall',
#  96610: 'Looper',
#  96691: 'Resident Evil: Retribution',
#  96737: 'Dredd',
#  96861: 'Taken 2',
#  97225: 'Hotel Transylvania',
#  97306: 'Seven Psychopaths',
#  97921: 'Silver Linings Playbook',
#  97923: 'Flight',
#  98809: 'Hobbit: An Unexpected Journey, The',
#  99112: 'Jack Reacher',
#  99114: 'Django Unchained',
#  101864: 'Oblivion',
#  102125: 'Iron Man 3',
#  102407: 'Great Gatsby, The',
#  102445: 'Star Trek Into Darkness',
#  102686: 'Hangover Part III, The',
#  102716: 'Fast & Furious 6 (Fast and the Furious 6, The)',
#  102880: 'After Earth',
#  102903: 'Now You See Me',
#  103075: 'Purge, The',
#  103141: 'Monsters University',
#  103228: 'Pacific Rim',
#  103249: 'World War Z',
#  103253: 'Elysium',
#  103384: 'Lone Ranger, The',
#  103772: 'Wolverine, The',
#  103810: 'Red 2',
#  104241: 'Kick-Ass 2',
#  104243: 'Riddick',
#  104841: 'Gravity',
#  105213: 'Don Jon',
#  106002: "Ender's Game",
#  106072: 'Thor: The Dark World',
#  106100: 'Dallas Buyers Club',
#  106487: 'The Hunger Games: Catching Fire',
#  106489: 'Hobbit: The Desolation of Smaug, The',
#  106782: 'Wolf of Wall Street, The',
#  106920: 'Her',
#  107348: 'Anchorman 2: The Legend Continues',
#  107406: 'Snowpiercer',
#  108190: 'Divergent',
#  108932: 'The Lego Movie',
#  108945: 'RoboCop',
#  109374: 'Grand Budapest Hotel, The',
#  109487: 'Interstellar',
#  109578: 'Non-Stop',
#  110102: 'Captain America: The Winter Soldier',
#  110407: 'Machine, The',
#  110730: 'Transcendence',
#  111113: 'Neighbors',
#  111360: 'Lucy',
#  111362: 'X-Men: Days of Future Past',
#  111443: 'Chef',
#  111659: 'Maleficent',
#  111759: 'Edge of Tomorrow',
#  112138: '22 Jump Street',
#  112171: 'Equalizer, The',
#  112370: 'Transformers: Age of Extinction',
#  112552: 'Whiplash',
#  112556: 'Gone Girl',
#  112623: 'Dawn of the Planet of the Apes',
#  112852: 'Guardians of the Galaxy',
#  113345: 'Jupiter Ascending',
#  114180: 'Maze Runner, The',
#  114847: 'Autómata (Automata)',
#  114935: 'Predestination',
#  115569: 'Nightcrawler',
#  115617: 'Big Hero 6',
#  115713: 'Ex Machina',
#  116797: 'The Imitation Game',
#  116823: 'The Hunger Games: Mockingjay - Part 1',
#  116897: 'Wild Tales',
#  117529: 'Jurassic World',
#  117533: 'Citizenfour',
#  120466: 'Chappie',
#  122882: 'Mad Max: Fury Road',
#  122886: 'Star Wars: Episode VII - The Force Awakens',
#  122892: 'Avengers: Age of Ultron',
#  122896: 'Pirates of the Caribbean: Dead Men Tell No Tales',
#  122900: 'Ant-Man',
#  122906: 'Black Panther',
#  122912: 'Avengers: Infinity War - Part I',
#  122914: 'Avengers: Infinity War - Part II',
#  122918: 'Guardians of the Galaxy 2',
#  122920: 'Captain America: Civil War',
#  122922: 'Doctor Strange',
#  122924: 'X-Men: Apocalypse',
#  129354: 'Focus',
#  130490: 'Insurgent',
#  130634: 'Furious 7',
#  132046: 'Tomorrowland',
#  134130: 'The Martian',
#  134853: 'Inside Out',
#  135133: 'The Hunger Games: Mockingjay - Part 2',
#  135143: 'Fantastic Beasts and Where to Find Them',
#  135536: 'Suicide Squad',
#  135569: 'Star Trek Beyond',
#  136020: 'Spectre',
#  136449: 'Ghost in the Shell 2.0',
#  136469: 'Larry David: Curb Your Enthusiasm',
#  136864: 'Batman v Superman: Dawn of Justice',
#  139385: 'The Revenant',
#  139644: 'Sicario',
#  140956: 'Ready Player One',
#  142509: 'Hardcore Henry',
#  143385: 'Bridge of Spies',
#  148626: 'Big Short, The',
#  148855: 'Ghost in the Shell: The New Movie',
#  149406: 'Kung Fu Panda 3',
#  151763: 'Death Note Rewrite: Genshisuru Kami',
#  158238: 'The Nice Guys',
#  158966: 'Captain Fantastic',
#  159093: 'Now You See Me 2',
#  164179: 'Arrival',
#  166528: 'Rogue One: A Star Wars Story',
#  166635: 'Passengers',
#  168252: 'Logan',
#  168612: 'Ghost in the Shell',
#  171763: 'Baby Driver',
#  175197: 'The Dark Tower',
#  176101: 'Kingsman: The Golden Circle',
#  176371: 'Blade Runner 2049',
#  179819: 'Star Wars: The Last Jedi',
#  182823: 'Bright',
#  187541: 'Incredibles 2',
#  187593: 'Deadpool 2',
#  1036: 'Die Hard',
#  1220: 'Blues Brothers, The',
#  1265: 'Groundhog Day',
#  1278: 'Young Frankenstein',
#  1288: 'This Is Spinal Tap',
#  2716: 'Ghostbusters (a.k.a. Ghost Busters)',
#  2791: 'Airplane!',
#  2951: 'Fistful of Dollars, A (Per un pugno di dollari)',
#  2985: 'RoboCop',
#  2993: 'Thunderball',
#  3033: 'Spaceballs',
#  3039: 'Trading Places',
#  3624: 'Shanghai Noon',
#  3671: 'Blazing Saddles',
#  3681: 'For a Few Dollars More (Per qualche dollaro in più)',
#  4709: 'Paint Your Wagon',
#  4974: 'Not Another Teen Movie',
#  5110: 'Super Troopers',
#  5299: 'My Big Fat Greek Wedding',
#  5444: 'Lilo & Stitch',
#  5618: 'Spirited Away (Sen to Chihiro no kamikakushi)',
#  7324: 'Hidalgo',
#  7451: 'Mean Girls',
#  7569: 'You Only Live Twice',
#  8914: 'Primer',
#  38038: 'Wallace & Gromit in The Curse of the Were-Rabbit',
#  44193: "She's the Man",
#  44665: 'Lucky Number Slevin',
#  45431: 'Over the Hedge',
#  46948: 'Monster House',
#  48982: 'Flushed Away',
#  49396: 'Tenacious D in The Pick of Destiny',
#  49649: 'Eragon',
#  50601: 'Bridge to Terabithia',
#  53956: 'Death at a Funeral',
#  54881: 'King of Kong, The',
#  68954: 'Up',
#  71264: 'Cloudy with a Chance of Meatballs',
#  72226: 'Fantastic Mr. Fox',
#  74530: 'Percy Jackson & the Olympians: The Lightning Thief',
#  76175: 'Clash of the Titans',
#  77866: 'Robin Hood',
#  78893: 'Last Airbender, The',
#  79185: 'Knight and Day',
#  79702: 'Scott Pilgrim vs. the World',
#  83134: 'Tucker & Dale vs Evil',
#  86345: 'Louis C.K.: Hilarious',
#  91485: 'Expendables 2, The',
#  93510: '21 Jump Street',
#  93838: 'The Raid: Redemption',
#  93840: 'Cabin in the Woods, The',
#  96110: 'Campaign, The',
#  97304: 'Argo',
#  97913: 'Wreck-It Ralph',
#  103341: "World's End, The",
#  106916: 'American Hustle',
#  111781: 'Mission: Impossible - Rogue Nation',
#  115122: 'What We Do in the Shadows',
#  115149: 'John Wick',
#  119145: 'Kingsman: The Secret Service',
#  122904: 'Deadpool',
#  127098: 'Louis C.K.: Live at The Comedy Store',
#  138036: 'The Man from U.N.C.L.E.',
#  142115: 'The Blue Planet',
#  148426: 'Fateful Findings',
#  152081: 'Zootopia',
#  156706: 'The Trust',
#  159817: 'Planet Earth',
#  168248: 'John Wick: Chapter Two',
#  171011: 'Planet Earth II',
#  173145: 'War for the Planet of the Apes',
#  174055: 'Dunkirk',
#  179401: 'Jumanji: Welcome to the Jungle',
#  180989: 'Alien Planet',
#  182715: 'Annihilation',
#  189333: 'Mission: Impossible - Fallout',
#  195159: 'Spider-Man: Into the Spider-Verse',
#  200818: 'John Wick: Chapter 3 – Parabellum',
#  200838: 'Pokémon: Detective Pikachu',
#  203375: 'Ford v. Ferrari',
#  203519: 'Fast & Furious Presents: Hobbs & Shaw',
#  19: 'Ace Ventura: When Nature Calls',
#  36: 'Dead Man Walking',
#  39: 'Clueless',
#  47: 'Seven (a.k.a. Se7en)',
#  88: 'Black Sheep',
#  95: 'Broken Arrow',
#  104: 'Happy Gilmore',
#  113: 'Before and After',
#  122: 'Boomerang',
#  141: 'Birdcage, The',
#  147: 'Basketball Diaries, The',
#  153: 'Batman Forever',
#  170: 'Hackers',
#  191: 'Scarlet Letter, The',
#  216: 'Billy Madison',
#  218: 'Boys on the Side',
#  219: 'Cure, The',
#  224: 'Don Juan DeMarco',
#  231: 'Dumb & Dumber (Dumb and Dumber)',
#  235: 'Ed Wood',
#  238: 'Far From Home: The Adventures of Yellow Dog',
#  248: 'Houseguest',
#  253: 'Interview with the Vampire: The Vampire Chronicles',
#  267: 'Major Payne',
#  277: 'Miracle on 34th Street',
#  288: 'Natural Born Killers',
#  292: 'Outbreak',
#  300: 'Quiz Show',
#  312: 'Stuart Saves His Family',
#  337: "What's Eating Gilbert Grape",
#  340: 'War, The',
#  342: "Muriel's Wedding",
#  344: 'Ace Ventura: Pet Detective',
#  350: 'Client, The',
#  372: 'Reality Bites',
#  416: 'Bad Girls',
#  432: "City Slickers II: The Legend of Curly's Gold",
#  435: 'Coneheads',
#  440: 'Dave',
#  441: 'Dazed and Confused',
#  477: "What's Love Got to Do with It?",
#  487: 'Lightning Jack',
#  491: 'Man Without a Face, The',
#  500: 'Mrs. Doubtfire',
#  542: 'Son in Law',
#  590: 'Dances with Wolves',
#  592: 'Batman',
#  595: 'Beauty and the Beast',
#  608: 'Fargo',
#  628: 'Primal Fear',
#  671: 'Mystery Science Theater 3000: The Movie',
#  736: 'Twister',
#  784: 'Cable Guy, The',
#  786: 'Eraser',
#  788: 'Nutty Professor, The',
#  802: 'Phenomenon',
#  839: 'Crow: City of Angels, The',
#  1016: 'Shaggy Dog, The',
#  1042: 'That Thing You Do!',
#  1047: 'Long Kiss Goodnight, The',
#  1061: 'Sleepers',
#  1073: 'Willy Wonka & the Chocolate Factory',
#  1093: 'Doors, The',
#  1097: 'E.T. the Extra-Terrestrial',
#  1120: 'People vs. Larry Flynt, The',
#  1194: "Cheech and Chong's Up in Smoke",
#  1234: 'Sting, The',
#  1235: 'Harold and Maude',
#  1290: 'Some Kind of Wonderful',
#  1344: 'Cape Fear',
#  1357: 'Shine',
#  1380: 'Grease',
#  1407: 'Scream',
#  1409: 'Michael',
#  161: 'Crimson Tide',
#  902: "Breakfast at Tiffany's",
#  919: 'Wizard of Oz, The',
#  1183: 'English Patient, The',
#  1203: '12 Angry Men',
#  ...}

# %%
def anti_list(userid):
  fill = trainset.global_mean
  anti_list = list()
  u = trainset.to_inner_uid(userid)
  user_items = set([item_inner_id for item_inner_id, rating in trainset.ur[u]])
  anti_list += [(trainset.to_raw_uid(u), trainset.to_raw_iid(i), fill) for i in trainset.all_items() if i not in user_items]
  return anti_list

# %%
def topn(userid, n=5):
  anti_testset = anti_list(userid)
  predict = svd.test(anti_testset)
  recommended = list()
  for uid, iid, actual_rating, estimated, _ in predict:
    mov_id = int(iid)
    recommended.append((mov_id, estimated))
  recommended.sort(key = lambda x: x[1], reverse = True)

  movie_name = []
  movie_rat = []

  for name, rating in recommended[:n]:
      movie_name.append(id_to_names[name])
      movie_rat.append(rating)

  return pd.DataFrame({'movie_name': movie_name, 'movie_estrat': movie_rat})

# %%
topn(18, 5)
# Out:
#                                           movie_name  movie_estrat
# 0            Harry Potter and the Chamber of Secrets      4.629846
# 1  Harry Potter and the Sorcerer's Stone (a.k.a. ...      4.609791
# 2                Harry Potter and the Goblet of Fire      4.593125
# 3           Harry Potter and the Prisoner of Azkaban      4.588536
# 4             Harry Potter and the Half-Blood Prince      4.501200

# %%
print('='*150)
# Out:
# ======================================================================================================================================================

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies['content'] = movies['genres'].str.replace('|', ' ')

# %%
movies['content'] = movies['content'].str.lower()

# %%
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies.isna().sum()
# Out:
# movieId    0
# title      0
# genres     0
# content    0
# dtype: int64

# %%
movies.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
movies.shape
# Out:
# (62423, 4)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies['movie_release_year'] = movies['title'].str.extract(r'\((\d{4})\)')
movies['movie_name'] = movies['title'].str.replace(r'\s*\(\d{4}\)', '', regex=True)

# %%
movies['movie_name'] = movies['movie_name'].str.lower()

# %%
content = movies['movie_name']+' '+movies['content']
content.head()
# Out:
# 0    toy story adventure animation children comedy ...
# 1                   jumanji adventure children fantasy
# 2                      grumpier old men comedy romance
# 3               waiting to exhale comedy drama romance
# 4                   father of the bride part ii comedy
# dtype: object

# %%
tf = TfidfVectorizer()

transformed_features = tf.fit_transform(content)

# %%
similarity = cosine_similarity(transformed_features)

# %%
all_movies_list = df['title'].tolist()

# %%
def recommend_movie(movie_name, df, sim):
    user_input = movie_name
    close_match= difflib.get_close_matches(user_input, all_movies_list, n = 5)[0]

    idx = df[df['title'] == close_match].index[0]
    similarity_score = list(enumerate(sim[idx]))
    sorted_score = sorted(similarity_score, key = lambda x:x[1], reverse = True)

    top_sim_score = sorted_score[1:11]
    rec_movies = [i[0] for i in top_sim_score]

    movies_list = df.iloc[rec_movies][['title', 'release_year']]

    return movies_list

# %%
recommend_movie('iron man', movies, similarity)

# %% [markdown]
# ==============================================================================================

# %%
userid = int(input('Enter your userid: '))
movie_name = input('Enter your movie name: ')


def hybrid():
  colabarative = topn(userid, n)
  content_based = recommend_movie(movie_name, movies, similarity)
  return colabarative.merge(content_based, on = 'movie_name')
